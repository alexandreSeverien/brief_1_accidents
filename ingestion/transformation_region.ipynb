# %%
import sys
sys.path.append("..")  # remonte d'un niveau vers le dossier parent
from utils.utils import connect_to_db, insert_data_to_db, mapping_colonnes, fetch_data_from_db
engine = connect_to_db()
df = fetch_data_from_db(table_name='accidents_raw', engine=engine, schema='bronze')
df
# Out:
# ✅ Connexion à la base PostgreSQL réussie !
# OK: "bronze"."accidents_raw"
#        Identifiant de l'accident              Date et heure  \
# 0                   201900031048  2019-11-09T14:30:00+01:00
# 1                   201900033371  2019-06-21T18:05:00+02:00
# 2                   201900035071  2019-06-23T03:20:00+02:00
# 3                   201400032968  2014-11-01T10:30:00+01:00
# 4                   201600013686  2016-06-26T13:40:00+02:00
# ...                          ...                        ...
# 475906              201200004488  2012-06-18T22:30:00+02:00
# 475907              201900026968  2019-07-29T16:20:00+02:00
# 475908              201900028113  2019-09-07T17:25:00+02:00
# 475909              201900028302  2019-06-28T09:45:00+02:00
# 475910              201900028440  2019-06-26T15:20:00+02:00
#
#                       Commune Année Mois Jour Heure minute  \
# 0                      Caudan  2019   11   09        14:30
# 1       Montereau-fault-yonne  2019   06   21        18:05
# 2                      Gigean  2019   06   23        03:20
# 3                      Tarbes  2014   11   01        10:30
# 4                   La Ciotat  2016   06   26        13:40
# ...                       ...   ...  ...  ...          ...
# 475906                Montech  2012   06   18        22:30
# 475907              Bannieres  2019   07   29        16:20
# 475908                 Lorris  2019   09   07        17:25
# 475909                   Volx  2019   06   28        09:45
# 475910               Sequedin  2019   06   26        15:20
#
#                            Lumière        Localisation Intersection  ...  \
# 0                       Plein jour    En agglomération            1  ...
# 1                       Plein jour    En agglomération            1  ...
# 2       Nuit sans éclairage public  Hors agglomération            1  ...
# 3                       Plein jour    En agglomération            1  ...
# 4                       Plein jour    En agglomération            1  ...
# ...                            ...                 ...          ...  ...
# 475906  Nuit sans éclairage public  Hors agglomération            1  ...
# 475907                  Plein jour  Hors agglomération            1  ...
# 475908                  Plein jour  Hors agglomération            1  ...
# 475909                  Plein jour  Hors agglomération            1  ...
# 475910                  Plein jour    En agglomération            6  ...
#
#        year_georef   Nom Officiel Commune Code Officiel Département  \
# 0             2019                 Caudan                        56
# 1             2019  Montereau-Fault-Yonne                        77
# 2             2019                 Gigean                        34
# 3             2015                 Tarbes                        65
# 4             2016              La Ciotat                        13
# ...            ...                    ...                       ...
# 475906        2015                Montech                        82
# 475907        2019              Bannières                        81
# 475908        2019                 Lorris                        45
# 475909        2019                   Volx                        04
# 475910        2019               Sequedin                        59
#
#        Nom Officiel Département Code Officiel EPCI  \
# 0                      Morbihan          200042174
# 1                Seine-et-Marne          247700107
# 2                       Hérault          200066355
# 3               Hautes-Pyrénées          246500565
# 4              Bouches-du-Rhône          200054807
# ...                         ...                ...
# 475906          Tarn-et-Garonne          248200180
# 475907                     Tarn          200034023
# 475908                   Loiret          200067676
# 475909  Alpes-de-Haute-Provence          200034700
# 475910                     Nord          245900410
#
#                               Nom Officiel EPCI Code Officiel Région  \
# 0                      CA Lorient Agglomération                   53
# 1                          CC Pays de Montereau                   11
# 2                CA Sète Agglopôle Méditerranée                   76
# 3                            CA du Grand Tarbes                   73
# 4            Métropole d'Aix-Marseille-Provence                   93
# ...                                         ...                  ...
# 475906                      CC Garonne et Canal                   73
# 475907                            CC Tarn-Agout                   76
# 475908          CC Canaux et Forêts en Gâtinais                   24
# 475909  CA Durance-Lubéron-Verdon Agglomération                   93
# 475910            Métropole Européenne de Lille                   32
#
#                Nom Officiel Région  \
# 0                         Bretagne
# 1                    Île-de-France
# 2                        Occitanie
# 3                    Midi-Pyrénées
# 4       Provence-Alpes-Côte d'Azur
# ...                            ...
# 475906               Midi-Pyrénées
# 475907                   Occitanie
# 475908         Centre-Val de Loire
# 475909  Provence-Alpes-Côte d'Azur
# 475910             Hauts-de-France
#
#        Nom Officiel Commune / Arrondissement Municipal Code Officiel Commune
# 0                                               Caudan                 56036
# 1                                Montereau-Fault-Yonne                 77305
# 2                                               Gigean                 34113
# 3                                               Tarbes                 65440
# 4                                            La Ciotat                 13028
# ...                                                ...                   ...
# 475906                                         Montech                 82125
# 475907                                       Bannières                 81022
# 475908                                          Lorris                 45187
# 475909                                            Volx                  4245
# 475910                                        Sequedin                 59566
#
# [475911 rows x 69 columns]

# %%
mapping_colonnes = {
    # --- Caractéristiques de l'accident (12) ---
    "Identifiant de l'accident": "num_acc",
    "Date et heure": "datetime",
    "Année": "an",
    "Mois": "mois",
    "Jour": "jour",
    "Heure minute": "hrmn",
    "Lumière": "lum",
    "Localisation": "agg",
    "Intersection": "int",
    "Conditions atmosphériques": "atm",
    "Collision": "col",
    "Situation": "situ",

    # --- Lieu (30) ---
    "Département": "dep",
    "Code commune": "com",
    "Code Insee": "insee",
    "Adresse": "adr",
    "Latitude": "lat",
    "Longitude": "long",
    "Code Postal": "code_postal",
    "Numéro": "num",
    "Coordonnées": "coordonnees",
    "PR": "pr",
    "Surface": "surf",
    "V1": "v1",
    "Circulation": "circ",
    "Voie réservée": "vosp",
    "Env1": "env1",
    "Voie": "voie",
    "Largeur de la chaussée": "larrout",
    "V2": "v2",
    "Largeur terre plein central": "lartpc",
    "Nombre de voies": "nbv",
    "Catégorie route": "catr",
    "PR1": "pr1",
    "Plan": "plan",
    "Profil": "prof",
    "Infrastructure": "infra",
    "Gps": "gps",
    "date": "date", 
    "year_georef": "year_georef",
    "Commune": "nom_com", 
    "Nom Officiel Commune": "com_name",

    # --- Usager (11) ---
    "Année de naissance": "an_nais",
    "Sexe": "sexe",
    "Action piéton": "actp",
    "Gravité": "grav",
    "Existence équipement de sécurité": "secu",
    "Utilisation équipement de sécurité": "secu_utl",
    "Localisation du piéton": "locp",
    "Place": "place",
    "Catégorie d'usager": "catu",
    "Piéton seul ou non": "etatp",
    "Motif trajet": "trajet",

    # --- Véhicule (8) ---
    "Identifiant véhicule": "num_veh",
    "Point de choc": "choc",
    "Manœuvre": "manv",
    "Sens": "senc",
    "Obstacle mobile heurté": "obsm",
    "Obstacle fixe heurté": "obs",
    "Catégorie véhicule": "catv",
    "Nombre d'occupants": "occutc",

    # --- Noms et Codes Officiels (8) ---
    "Code Officiel Département": "dep_code", 
    "Nom Officiel Département": "dep_name",
    "Code Officiel EPCI": "epci_code",       
    "Nom Officiel EPCI": "epci_name",
    "Code Officiel Région": "reg_code",       
    "Nom Officiel Région": "reg_name",
    "Nom Officiel Commune / Arrondissement Municipal": "com_arm_name",
    "Code Officiel Commune": "code_com"         
}

len(mapping_colonnes)
# Out:
# 69

# %%
df = df.rename(columns=mapping_colonnes)

# --- Colonnes à conserver selon la table silver.region ---
colonnes_region = ["reg_code", "reg_name", "gps"]

# --- Vérifier que les colonnes existent et les filtrer ---
colonnes_disponibles = [col for col in colonnes_region if col in df.columns]

if not colonnes_disponibles:
    raise ValueError("⚠️ Aucune des colonnes ['reg_code', 'reg_name', 'gps'] n'existe dans accidents_raw.")

df_region = df[colonnes_disponibles]

print("✅ Données filtrées pour la table 'silver.region' :")
# Out:
# ✅ Données filtrées pour la table 'silver.region' :

# %%
# Supprimer les doublons sur reg_code (car c’est une clé unique)
df_region = df_region.drop_duplicates(subset="reg_code", keep="first")
#supprimer les lignes vide
df_region = df_region.dropna(how="all")

df_region = df_region.sort_values(by="reg_code", ascending=True)
print(df_region.head(10))
# Out:
#      reg_code             reg_name                                  gps
# 411        01           Guadeloupe  Antilles (Martinique ou Guadeloupe)
# 342        02           Martinique  Antilles (Martinique ou Guadeloupe)
# 639        03               Guyane                               Guyane
# 675        04           La Réunion                                 None
# 2286       06              Mayotte                              Mayotte
# 1          11        Île-de-France                                 None
# 82         21    Champagne-Ardenne                            Métropole
# 86         22             Picardie                                 None
# 65         23      Haute-Normandie                            Métropole
# 21         24  Centre-Val de Loire                            Métropole

# %%
print("🔍 Valeurs manquantes avant nettoyage :")
print(df_region.isna().sum())
# Supprimer les lignes sans reg_code ou reg_name (indispensables)
df_region = df_region.dropna(subset=["reg_code", "reg_name"])
# Remplacer les valeurs manquantes de gps / reg_name par 'Inconnu' (ou None selon ton choix)
df_region["reg_name"] = df_region["reg_name"].fillna("Inconnu")
df_region["gps"] = df_region["gps"].fillna("Inconnu")
# Out:
# 🔍 Valeurs manquantes avant nettoyage :
# reg_code     1
# reg_name     1
# gps         10
# dtype: int64

# %%
print("✅ Aperçu des données nettoyées :")
print(df_region.head(10))
print("🔍 Nombre de valeurs nulles par colonne :")
print(df_region.isna().sum())
# Out:
# ✅ Aperçu des données nettoyées :
#      reg_code             reg_name                                  gps
# 411        01           Guadeloupe  Antilles (Martinique ou Guadeloupe)
# 342        02           Martinique  Antilles (Martinique ou Guadeloupe)
# 639        03               Guyane                               Guyane
# 675        04           La Réunion                              Inconnu
# 2286       06              Mayotte                              Mayotte
# 1          11        Île-de-France                              Inconnu
# 82         21    Champagne-Ardenne                            Métropole
# 86         22             Picardie                              Inconnu
# 65         23      Haute-Normandie                            Métropole
# 21         24  Centre-Val de Loire                            Métropole
# 🔍 Nombre de valeurs nulles par colonne :
# reg_code    0
# reg_name    0
# gps         0
# dtype: int64

# %%
insert_data_to_db(df_region, table_name='silver.region', engine=engine)
